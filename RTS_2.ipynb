# %%
import pandas as pd
accident_data = pd.read_csv("Master_Accident_Data.csv")
accident_data
# Out:
#          accdate   Operator_ID                              AccTypeCodeDescr  \
# 0      3/15/2017          365.0               Vehicle Approaching From Angle
# 1      5/18/2016          173.0                              Vehicle Passing
# 2      9/12/2018          329.0         Collisions with other motor vehicles
# 3       5/7/2019          276.0               Vehicle Approaching From Angle
# 4      5/12/2015           42.0  Passenger On Board Thrown By RGRTA Movement
# 5      12/6/2016          461.0                   Collisions w/Other Objects
# 6      6/20/2017           62.0                      Vehicle Operating Ahead
# 7      7/15/2015          241.0         Collisions with other motor vehicles
# 8      9/27/2016          345.0         Collisions with other motor vehicles
# 9       3/1/2017          361.0                   Collisions w/Fixed Objects
# 10     2/24/2016           55.0                   Collisions w/Other Objects
# ...

# %%
for i in range (1314, 1540,1):
    accident_data.drop(i,inplace=True)

# %%
accident_data.shape
# Out:
# (1314, 23)

# %%
accident_data
# Out:
#          accdate   Operator_ID                              AccTypeCodeDescr  \
# 0      3/15/2017          365.0               Vehicle Approaching From Angle
# 1      5/18/2016          173.0                              Vehicle Passing
# 2      9/12/2018          329.0         Collisions with other motor vehicles
# 3       5/7/2019          276.0               Vehicle Approaching From Angle
# 4      5/12/2015           42.0  Passenger On Board Thrown By RGRTA Movement
# 5      12/6/2016          461.0                   Collisions w/Other Objects
# 6      6/20/2017           62.0                      Vehicle Operating Ahead
# 7      7/15/2015          241.0         Collisions with other motor vehicles
# 8      9/27/2016          345.0         Collisions with other motor vehicles
# 9       3/1/2017          361.0                   Collisions w/Fixed Objects
# 10     2/24/2016           55.0                   Collisions w/Other Objects
# ...

# %%
acctypelist = []
for i in range (0,1314,1):
    x = accident_data['acctype'][i]
    if x =='03 - MVA with Vehicle' or x =='03 - MVA with Vehicle ( Hit & Run )':
        acctypelist.append(3)
    elif x =='06 - On Board Injury/Incident':
        acctypelist.append(6)
    elif x =='02 - MVA with Injuries':
        acctypelist.append(2)
    elif x =='04 - MVA with Fixed Object':
        acctypelist.append(4)
    elif x =='10 - Other':
        acctypelist.append(10)
    elif x =='01 - Pedestrian Struck MVA':
        acctypelist.append(1)
    elif x =='05 - Boarding or Alighting Injury/Incide':
        acctypelist.append(1)
    elif x =='6':
        acctypelist.append(6)
    elif pd.isnull(x):
        acctypelist.append(-1)
    
    else:
        print(accident_data['acctype'][i])
        acctypelist.append(0)
        


accident_data['acctypenum'] = acctypelist

# %%
len(acctypelist)
# Out:
# 1314

# %%
import seaborn as sns
sns.set(style="darkgrid")
ax = sns.countplot(x="acctypenum", data=accident_data)

# %%
# for i in range(0,1314,1):
#     accident_data['Drv_Age'][i]=int(accident_data['Drv_Age'][i])
#     print(accident_data['Drv_Age'][i])

# %%
# accident_data['Drv_Age'][997]=int(accident_data['Drv_Age'][997])

# %%
accident_data['Drv_Age'][997]
# Out:
# '  '

# %%
for i in range(0,1314,1):
    if accident_data['Drv_Age'][i] =='  ':
        accident_data['Drv_Age'][i] = '40'
# Out:
# C:\Users\qiany\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
drv_age_list =[]
for i in range(0, 1314,1):
    x = accident_data['Drv_Age'][i][1:3]
    drv_age_list.append(x)
drv_age_list2=[]
for i in range(0, 1314,1):
    x = int(drv_age_list[i])
    drv_age_list2.append(x)
accident_data['drv_age_int']=drv_age_list2

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

accident_data['drv_age_int'].hist(bins=20)
plt.title('Driver Ages')
plt.xlabel('Ages')
plt.ylabel('Count')
# plt.grid(axis='y', alpha=0.75)
# Out:
# Text(0, 0.5, 'Count')

# %%
countf =0
countm= 0
for i in range (0,1314,1):
    if accident_data['CoDrvSex'][i] =="F":
        countf = countf+1
    elif accident_data['CoDrvSex'][i] =="M" or "m":
        countm = countm+1
    else:
        print(accident_data['CoDrvSex'][i])
        
print(countf)
print(countm)
# Out:
# 313
# 1001

# %%
labels = 'male driver', 'female driver'
sizes = [1001,313]
plt.pie(sizes,  labels=labels, 
autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d0cdb96470>,
# ...
#  [Text(0.13640532612710024, -1.0915097741221376, 'male driver'),
#   Text(-0.13640537722436066, 1.0915097677365422, 'female driver')],
#  [Text(0.0744029051602365, -0.595368967702984, '76.2%'),
#   Text(-0.07440293303146944, 0.595368964219932, '23.8%')])

# %%
#sort the data by date 
accident_data['accdate'] =pd.to_datetime(accident_data['accdate'])

# %%
sort_data =accident_data.sort_values(by = 'accdate')
sort_data
# Out:
#         accdate   Operator_ID                              AccTypeCodeDescr  \
# 128  2014-08-01          480.0     Collisions w/RGRTA vehicles (Bus to Bus)
# 118  2014-08-04           22.0               Vehicle Approaching From Angle
# 143  2014-08-05          209.0                      Vehicle Operating Ahead
# 877  2014-08-05          187.0                              Vehicle Passing
# 430  2014-08-05          285.0         Thrown by movement of RGRTA stopping
# 521  2014-08-06          211.0                   Collisions w/Fixed Objects
# 890  2014-08-08          212.0                              Vehicle Passing
# 1233 2014-08-09          216.0         Collisions with other motor vehicles
# 1031 2014-08-10          245.0               Vehicle Approaching From Angle
# 253  2014-08-12           58.0  Passenger On Board Thrown By RGRTA Movement
# 1151 2014-08-14          259.0     Collisions w/RGRTA vehicles (Bus to Bus)
# ...

# %%
# retrain =accident_data[(accident_data['Retraining']=="N") & 
#                        (accident_data['AccPreventable']=="Preventable")]
# retrain

# %%
retrain =sort_data[(accident_data['Retraining']=="Y") ]
retrain =retrain.reset_index(drop=True)
# Out:
# C:\Users\qiany\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
retrain
# Out:
#        accdate   Operator_ID                           AccTypeCodeDescr  \
# 0   2014-08-01          480.0  Collisions w/RGRTA vehicles (Bus to Bus)
# 1   2014-08-04           22.0            Vehicle Approaching From Angle
# 2   2014-08-09          216.0      Collisions with other motor vehicles
# 3   2014-08-14          259.0  Collisions w/RGRTA vehicles (Bus to Bus)
# 4   2014-08-19          443.0               Equipment damage or failure
# 5   2014-08-20          100.0                Collisions w/Other Objects
# 6   2014-08-26          448.0                                       NaN
# 7   2014-08-26          445.0  Collisions w/RGRTA vehicles (Bus to Bus)
# 8   2014-08-27          466.0  Collisions w/RGRTA vehicles (Bus to Bus)
# 9   2014-08-27           61.0                Collisions w/Other Objects
# 10  2014-08-28          172.0                Collisions w/Fixed Objects
# 11  2014-09-11          197.0                Collisions w/Other Objects
# ...

# %%
retrain.to_csv("retrain.csv")

# %%
retrain[retrain['RoadwayLightConditions']!= "Daylight"]
# Out:
#        accdate   Operator_ID                           AccTypeCodeDescr  \
# 4   2014-08-19          443.0               Equipment damage or failure
# 6   2014-08-26          448.0                                       NaN
# 11  2014-09-11          197.0                Collisions w/Other Objects
# 18  2014-09-30          241.0                           Vehicle Passing
# 19  2014-10-01          204.0            Vehicle Approaching From Angle
# 20  2014-10-03          433.0                Collisions w/Fixed Objects
# 21  2014-10-07          304.0          RGRTA Passing Stationary Vehicle
# 24  2014-10-12          305.0  Collisions w/RGRTA vehicles (Bus to Bus)
# 26  2014-10-17           11.0  Collisions w/RGRTA vehicles (Bus to Bus)
# 27  2014-10-22           97.0            Vehicle Approaching From Angle
# 32  2014-11-12          446.0                           Vehicle Passing
# 33  2014-11-13          211.0                           Vehicle Passing
# ...

# %%
id_list =retrain[' Operator_ID '].tolist()
len(id_list)
# Out:
# 636

# %%
retrain[' Operator_ID ']
# Out:
# 0      480.0
# 1       22.0
# 2      216.0
# 3      259.0
# 4      443.0
# 5      100.0
# 6      448.0
# 7      445.0
# 8      466.0
# 9       61.0
# 10     172.0
# 11     197.0
# 12     237.0
# 13     252.0
# 14     185.0
# 15     240.0
# 16       1.0
# 17     239.0
# 18     241.0
# 19     204.0
# 20     433.0
# 21     304.0
# 22      66.0
# 23     440.0
# 24     305.0
# 25     139.0
# 26      11.0
# 27      97.0
# 28     437.0
# 29      37.0
#        ...
# 606     66.0
# 607    125.0
# 608     52.0
# 609    373.0
# 610    156.0
# 611    115.0
# 612    237.0
# 613    153.0
# 614    511.0
# 615     61.0
# 616    427.0
# 617    127.0
# 618    426.0
# 619    357.0
# 620     71.0
# 621     62.0
# 622    261.0
# 623    524.0
# 624    150.0
# 625    429.0
# 626    460.0
# 627    337.0
# 628     38.0
# 629    332.0
# 630    402.0
# 631     22.0
# 632    428.0
# 633    470.0
# 634    245.0
# 635    388.0
# Name:  Operator_ID , Length: 636, dtype: float64

# %%
# def list_duplicates_of(seq,item):
#     start_at = -1
#     locs = []
#     while True:
#         try:
#             loc = seq.index(item,start_at+1)
#         except ValueError:
#             break
#         else:
#             locs.append(loc)
#             start_at = loc
#     return locs

# source = "ABABDBAAEDSBQEWBAFLSAFB"
# print(list_duplicates_of(source, 'B'))

# %%
import datetime
import pandas as pd
import numpy as np

columns = ['operator_id', 'acc_count','age','acc_date','last_date','acc_index',
           'weather','surface','atten_weather','atten_surface','special_light_count','weather_special','surface_special']
todays_date = datetime.datetime.now().date()
index = range(360)


df2 = pd.DataFrame(index=index, columns=columns)
df2
# Out:
#     operator_id acc_count  age acc_date last_date acc_index weather surface  \
# 0           NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# 1           NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# 2           NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# 3           NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# 4           NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# 5           NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# 6           NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# 7           NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# 8           NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# 9           NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# 10          NaN       NaN  NaN      NaN       NaN       NaN     NaN     NaN
# ...

# %%
# def to_str(var):
#     return str(list(np.reshape(np.asarray(var), (1, np.size(var)))[0]))[1:-1]

# %%
import collections
d = collections.defaultdict(list)
# l = ['A','A','B','A','B','B','A']
l = [1,2,2,2,3,1,3,1]
for index, e in enumerate(l):
    d[e].append(index)
print(d[1])
# Out:
# [0, 5, 7]

# %%
def remove_dup(duplicate): 
    final_list = [] 
    for num in duplicate: 
        if num not in final_list: 
            final_list.append(num) 
    return final_list

# %%
count2 =0
the_list=[]
for i in range (0, 635):
    if retrain[' Operator_ID '][i] in the_list:
        print("already in list")
    else:
        count = id_list.count(retrain[' Operator_ID '][i])
        the_list.append(retrain[' Operator_ID '][i])
        d = collections.defaultdict(list)
        for index, e in enumerate(id_list):
            d[e].append(index)
        print(d[retrain[' Operator_ID '][i]])
        last = d[retrain[' Operator_ID '][i]]
        
        road_weather =[]
        road_surface =[]
        nd_road_weather=[]
        nd_road_surface=[]
        
        
        for z in range (len(last)):
            road_weather.append(retrain['RoadwayWeather'][last[z]])
            road_surface.append(retrain['RoadwaySurface'][last[z]])
        nd_road_weather = remove_dup(road_weather)
        nd_road_surface = remove_dup(road_surface)
        state = []
        
        count4=0
        for q in range (len(last)):
            if retrain['RoadwayLightConditions'][last[q]]!="Daylight":
                print(retrain['RoadwayLightConditions'][last[q]])
                count4 =count4+1
        count5=0                                                  
        for b in range (len(last)):
            if retrain['RoadwayWeather'][last[b]]!="Clear":
                print(retrain['RoadwayWeather'][last[b]])
                count5 = count5+1
        count6=0
        for n in range (len(last)):
            if retrain['RoadwaySurface'][last[n]]!="Dry":
                print(retrain['RoadwaySurface'][last[n]])
                count6 = count6+1 

                        
                                                          
                                                        
                                                        
        df2['special_light_count'][count2]=count4
        df2['weather_special'][count2]=count5                                                 
        df2['surface_special'][count2]=count6        
        
        
        for x in range(len(nd_road_weather)):
            count3 = 0
            count3= road_weather.count(nd_road_weather[x])
            if count3 >2:
                state.append(nd_road_weather[x])
                print("sssssssssssss")
                print(state)
        state2 = []
        for t in range(len(nd_road_surface)):
            count10 = 0
            count10= road_weather.count(nd_road_surface[t])
            if count10 >2:
                state2.append(nd_road_surface[t])
                print("sssssssssssss")
                print(state2)
                
        df2['atten_weather'][count2]=state
        df2['atten_surface'][count2]=state2
        print(road_weather)
        print(road_surface)
        
        df2['weather'][count2]=road_weather
        df2['surface'][count2]=road_surface
        df2['acc_index'][count2] = last
        df2['last_date'][count2] = retrain['accdate'][last[-1]]
        df2['acc_date'][count2] = retrain['accdate'][i]
        df2['operator_id'][count2] = retrain[' Operator_ID '][i]
        df2['age'][count2] =int(retrain['Drv_Age'][i])
        df2['acc_count'][count2] = count
        count2= count2 +1
# Out:
# [0, 47, 148, 436, 530]
# Dark
# nan
# Dark, but Lighted
# nan
# Rain
# Snow
# nan
# nan
# Wet
# Snow
# nan
# Slush
# nan
# ['Rain', 'Snow', nan, 'Clear', nan]
# ['Wet', 'Snow', nan, 'Slush', nan]
# C:\Users\qiany\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\qiany\Anaconda3\lib\site-packages\ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\qiany\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
retrain[' Operator_ID '][562]
# Out:
# 83.0

# %%
df2
# Out:
#     operator_id acc_count  age             acc_date            last_date  \
# 0           480         5   47  2014-08-01 00:00:00  2018-10-04 00:00:00
# 1            22         3   73  2014-08-04 00:00:00  2019-07-23 00:00:00
# 2           216         1   43  2014-08-09 00:00:00  2014-08-09 00:00:00
# 3           259         1   52  2014-08-14 00:00:00  2014-08-14 00:00:00
# 4           443         2   51  2014-08-19 00:00:00  2016-06-06 00:00:00
# 5           100         1   66  2014-08-20 00:00:00  2014-08-20 00:00:00
# 6           448         2   46  2014-08-26 00:00:00  2015-01-12 00:00:00
# 7           445         1   59  2014-08-26 00:00:00  2014-08-26 00:00:00
# 8           466         1   58  2014-08-27 00:00:00  2014-08-27 00:00:00
# 9            61         5   51  2014-08-27 00:00:00  2019-06-10 00:00:00
# 10          172         2   65  2014-08-28 00:00:00  2018-05-21 00:00:00
# 11          197         5   54  2014-09-11 00:00:00  2018-03-19 00:00:00
# ...

# %%
df2['diff_days'] = df2['last_date'] -df2['acc_date']

# %%
df2['diff_days']=df2['diff_days']/np.timedelta64(1,'D')

# %%
df2
# Out:
#     operator_id acc_count  age             acc_date            last_date  \
# 0           480         5   47  2014-08-01 00:00:00  2018-10-04 00:00:00
# 1            22         3   73  2014-08-04 00:00:00  2019-07-23 00:00:00
# 2           216         1   43  2014-08-09 00:00:00  2014-08-09 00:00:00
# 3           259         1   52  2014-08-14 00:00:00  2014-08-14 00:00:00
# 4           443         2   51  2014-08-19 00:00:00  2016-06-06 00:00:00
# 5           100         1   66  2014-08-20 00:00:00  2014-08-20 00:00:00
# 6           448         2   46  2014-08-26 00:00:00  2015-01-12 00:00:00
# 7           445         1   59  2014-08-26 00:00:00  2014-08-26 00:00:00
# 8           466         1   58  2014-08-27 00:00:00  2014-08-27 00:00:00
# 9            61         5   51  2014-08-27 00:00:00  2019-06-10 00:00:00
# 10          172         2   65  2014-08-28 00:00:00  2018-05-21 00:00:00
# 11          197         5   54  2014-09-11 00:00:00  2018-03-19 00:00:00
# ...

# %%
for i in range (0, 699):
    df2['frequency'] = df2['diff_days']/df2['acc_count']
df2
# Out:
#     operator_id acc_count  age             acc_date            last_date  \
# 0           480         5   47  2014-08-01 00:00:00  2018-10-04 00:00:00
# 1            22         3   73  2014-08-04 00:00:00  2019-07-23 00:00:00
# 2           216         1   43  2014-08-09 00:00:00  2014-08-09 00:00:00
# 3           259         1   52  2014-08-14 00:00:00  2014-08-14 00:00:00
# 4           443         2   51  2014-08-19 00:00:00  2016-06-06 00:00:00
# 5           100         1   66  2014-08-20 00:00:00  2014-08-20 00:00:00
# 6           448         2   46  2014-08-26 00:00:00  2015-01-12 00:00:00
# 7           445         1   59  2014-08-26 00:00:00  2014-08-26 00:00:00
# 8           466         1   58  2014-08-27 00:00:00  2014-08-27 00:00:00
# 9            61         5   51  2014-08-27 00:00:00  2019-06-10 00:00:00
# 10          172         2   65  2014-08-28 00:00:00  2018-05-21 00:00:00
# 11          197         5   54  2014-09-11 00:00:00  2018-03-19 00:00:00
# ...

# %%
df2.to_csv("df2.csv")

# %%
type(df2['age'][5])
# Out:
# int

# %%
age_list =df2['acc_count'].tolist()
max(age_list)
# Out:
# 11

# %%
df3 =df2[(df2['frequency']!=0 )]
df3
# retrain =sort_data[(accident_data['Retraining']=="Y") ]
# Out:
#     operator_id acc_count  age             acc_date            last_date  \
# 0           480         5   47  2014-08-01 00:00:00  2018-10-04 00:00:00
# 1            22         3   73  2014-08-04 00:00:00  2019-07-23 00:00:00
# 4           443         2   51  2014-08-19 00:00:00  2016-06-06 00:00:00
# 6           448         2   46  2014-08-26 00:00:00  2015-01-12 00:00:00
# 9            61         5   51  2014-08-27 00:00:00  2019-06-10 00:00:00
# 10          172         2   65  2014-08-28 00:00:00  2018-05-21 00:00:00
# 11          197         5   54  2014-09-11 00:00:00  2018-03-19 00:00:00
# 12          237         4   49  2014-09-14 00:00:00  2019-05-26 00:00:00
# 13          252         4   48  2014-09-15 00:00:00  2018-01-27 00:00:00
# 14          185         4   57  2014-09-18 00:00:00  2017-05-18 00:00:00
# 15          240         3   50  2014-09-22 00:00:00  2017-11-01 00:00:00
# 16            1         2   65  2014-09-29 00:00:00  2017-01-03 00:00:00
# ...

# %%
plt.scatter(df3['age'],df3['frequency'])
plt.xlabel("age")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
df2[df2['special_light_count']!=0]
# Out:
#     operator_id acc_count  age             acc_date            last_date  \
# 0           480         5   47  2014-08-01 00:00:00  2018-10-04 00:00:00
# 1            22         3   73  2014-08-04 00:00:00  2019-07-23 00:00:00
# 4           443         2   51  2014-08-19 00:00:00  2016-06-06 00:00:00
# 6           448         2   46  2014-08-26 00:00:00  2015-01-12 00:00:00
# 9            61         5   51  2014-08-27 00:00:00  2019-06-10 00:00:00
# 11          197         5   54  2014-09-11 00:00:00  2018-03-19 00:00:00
# 12          237         4   49  2014-09-14 00:00:00  2019-05-26 00:00:00
# 13          252         4   48  2014-09-15 00:00:00  2018-01-27 00:00:00
# 14          185         4   57  2014-09-18 00:00:00  2017-05-18 00:00:00
# 18          241         5   42  2014-09-30 00:00:00  2016-06-23 00:00:00
# 19          204         1   37  2014-10-01 00:00:00  2014-10-01 00:00:00
# 20          433         1   57  2014-10-03 00:00:00  2014-10-03 00:00:00
# ...

# %%
import pandas as pd
df2 = pd.read_csv("df2.csv")

# %%
df3 =df2[df2['frequency']!=0]

# %%
import matplotlib.pyplot as plt
df3[['frequency']].plot(kind='hist',bins=[0,300,600,900,1200],rwidth=0.8, color = 'pink')
plt.xlabel("accident frequency")
plt.ylabel("count")

plt.show()

# %%
df2['perc_special_light'] = df2['special_light_count']/df2['acc_count']

# %%
df2['perc_weather'] =df2['weather_special']/df2['acc_count']

# %%
df2['perc_surface'] =df2['surface_special']/df2['acc_count']
df2['sum'] = df2['perc_special_light']+df2['perc_weather'] +df2['perc_surface']

# %%
df4 = df2[df2['acc_count']>2]

# %%
df4
# Out:
#      Unnamed: 0  operator_id  acc_count   age         acc_date  \
# 0             0        480.0        5.0  47.0    8/1/2014 0:00
# 1             1         22.0        3.0  73.0    8/4/2014 0:00
# 9             9         61.0        5.0  51.0   8/27/2014 0:00
# 11           11        197.0        5.0  54.0   9/11/2014 0:00
# 12           12        237.0        4.0  49.0   9/14/2014 0:00
# 13           13        252.0        4.0  48.0   9/15/2014 0:00
# 14           14        185.0        4.0  57.0   9/18/2014 0:00
# 15           15        240.0        3.0  50.0   9/22/2014 0:00
# 17           17        239.0        3.0  41.0   9/29/2014 0:00
# 18           18        241.0        5.0  42.0   9/30/2014 0:00
# 22           22         66.0        5.0  56.0   10/7/2014 0:00
# 29           29         37.0        3.0  51.0   11/3/2014 0:00
# 43           43        153.0        4.0  55.0   12/8/2014 0:00
# 44           44        472.0        3.0  38.0   12/9/2014 0:00
# ...

# %%
plt.scatter(df4['age'],df4['sum'])
plt.xlabel("age ")
plt.ylabel("sum score")
# Out:
# Text(0, 0.5, 'sum score')

# %%
def average(lst): 
    return sum(lst) / len(lst)

# %%
avg_sum =[]
df = df4[df4['acc_count'] == 3]
l =df['sum'].tolist()
avg_sum.append(average(l))

# %%
df = df4[df4['acc_count'] == 4]
l =df['sum'].tolist()
average(l)
avg_sum.append(average(l))

# %%
df = df4[df4['acc_count'] == 5]
l =df['sum'].tolist()
average(l)
avg_sum.append(average(l))

# %%
df = df4[df4['acc_count'] == 6]
l =df['sum'].tolist()
average(l)
avg_sum.append(average(l))

# %%
avg_sum
# Out:
# [1.1196581196581197,
#  1.1470588235294117,
#  1.4923076923076921,
#  1.9166666666666665]

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
objects = ('3', '4', '5', '6')
y_pos = np.arange(len(objects))
performance =avg_sum

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('average sum')
plt.xlabel('number of accident ')


plt.show()

# %%
df4[['perc_surface']].plot(kind='hist',bins=[0,0.2,0.4,0.6,0.8,1],rwidth=0.8)
plt.xlabel("special surface accident frequency")
plt.ylabel("count")
plt.ylim([0,30])
plt.show()

# %%
df4[['perc_weather']].plot(kind='hist',bins=[0,0.2,0.4,0.6,0.8,1],rwidth=0.8)
plt.xlabel("special weather accident frequency")
plt.ylabel("count")
plt.ylim([0,30])
plt.show()

# %%
df4[['perc_special_light']].plot(kind='hist',bins=[0,0.2,0.4,0.6,0.8,1],rwidth=0.8)
plt.xlabel("special road light accident frequency")
plt.ylabel("count")
plt.ylim([0,30])
plt.show()

# %%
df4
# Out:
#      Unnamed: 0  operator_id  acc_count   age         acc_date  \
# 0             0        480.0        5.0  47.0    8/1/2014 0:00
# 1             1         22.0        3.0  73.0    8/4/2014 0:00
# 9             9         61.0        5.0  51.0   8/27/2014 0:00
# 11           11        197.0        5.0  54.0   9/11/2014 0:00
# 12           12        237.0        4.0  49.0   9/14/2014 0:00
# 13           13        252.0        4.0  48.0   9/15/2014 0:00
# 14           14        185.0        4.0  57.0   9/18/2014 0:00
# 15           15        240.0        3.0  50.0   9/22/2014 0:00
# 17           17        239.0        3.0  41.0   9/29/2014 0:00
# 18           18        241.0        5.0  42.0   9/30/2014 0:00
# 22           22         66.0        5.0  56.0   10/7/2014 0:00
# 29           29         37.0        3.0  51.0   11/3/2014 0:00
# 43           43        153.0        4.0  55.0   12/8/2014 0:00
# 44           44        472.0        3.0  38.0   12/9/2014 0:00
# ...

# %%
df4.to_csv("df4.csv")
